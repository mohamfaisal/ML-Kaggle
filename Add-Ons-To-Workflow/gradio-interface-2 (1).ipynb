# %%
import gradio as gr

def calculate(a, b, operation):
    if operation == "Addition":
        return a + b
    elif operation == "Multiplication":
        return a * b
    elif operation == "Subtraction":
        return a - b
    elif operation == "Division":
        return a / b if b != 0 else "Error: Division by zero"

demo = gr.Interface(
    fn=calculate,
    inputs=[
        gr.Number(label="Number 1"),
        gr.Number(label="Number 2"),
        gr.Dropdown(["Addition", "Multiplication", "Subtraction", "Division"], label="Choose Operation")
    ],
    outputs=gr.Textbox(label="Result"),
    title="Math Calculator"
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# * Running on public URL: https://3c810d4decd71346b1.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3c810d4decd71346b1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
